# %%
import numpy as np
import xarray as xr
import matplotlib
import matplotlib.pylab as plt

# %%
#each of the 3IFS runs (2.8km.4km,9km) is stored in one zarr
ds_ifs = xr.open_zarr('/work/bm1235/a270046/cycle2-sync/ddh_output/4km')

# %%
ds_icon = xr.open_zarr('/work/bm1235/k203123/experiments/ngc2009/outdata/ngc2009_mtgrm.zarr')

# %% [markdown]
# # Locations of Cabauw differ
#
# Location of Cabauw slightly differ in ICON and IFS:
#
# Links to Google maps:
# - [ICON](https://www.google.com/maps/place/51%C2%B058'12.0%22N+4%C2%B055'48.0%22E/@51.9690271,4.8769101,12.63z/data=!4m5!3m4!1s0x0:0x50549fecc97842d!8m2!3d51.97!4d4.93)
# - [IFS](https://www.google.com/maps/place/51%C2%B058'12.0%22N+4%C2%B053'24.0%22E/@51.9742767,4.8649014,12.33z/data=!4m5!3m4!1s0x0:0x619b47c2ac4345fe!8m2!3d51.97!4d4.89)
#
#
# The distance is about 2-3km.

# %%
ds_icon.sel(station=ds_icon.station == 'Cabauw').lon.load()
# Out:
# <xarray.DataArray 'lon' (station: 1)>
# array([4.93])
# Coordinates:
#     blk      (station) int32 131255
#     dx       (station) int32 22
#     lat      (station) float64 51.97
#     lon      (station) float64 4.93
#   * station  (station) <U44 'Cabauw'
# Attributes:
#     description:  Longitude of meteogram station

# %%
ds_ifs.sel(station=ds_ifs.station_name=='CABAUW_NL').lon.load()
# Out:
# <xarray.DataArray 'lon' (station: 1)>
# array([4.89])
# Coordinates:
#   * station       (station) int64 12
#     station_name  (station) <U26 'CABAUW_NL'
# Attributes:
#     units:    degrees_east
